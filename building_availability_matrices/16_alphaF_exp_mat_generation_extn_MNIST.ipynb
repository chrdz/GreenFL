# %% [markdown]
# # Evaluating the output of the SCIP solver of CVXPY

# %%
from av_mat_generation.CI_based.window import Window
from datetime import datetime
import pandas as pd
import numpy as np
import cvxpy as cp
MAIN_FOLDER = 'availability_matrices/av-mat-extn-idle'

start_time=datetime(2022, 1, 1, 0, 0)
win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100)
res = win.get_GHG_matrix()
min_carbon_budget = res[[i for i in range(97,100)]].sum().sum()
total_cb = res.sum().sum()
print(1-min_carbon_budget/total_cb)

print('Total cb: ', total_cb)

win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100)
# Out:
# 0.9636773886552453
# Total cb:  24.152889

# %%
tmp = res.sum().cumsum().to_numpy()

# %%
tmp.take([99])
# Out:
# array([24.152889], dtype=object)

# %%
carbon_budget_considered = res.sum().cumsum().to_numpy().take([39, 29, 19, 9, 4, 3, 2])
print(carbon_budget_considered)

# _3FT_CB = [7.980065999999999,6.1960109999999995,4.235079,1.983414,1.773765,0.9428550000000001,0.7447260000000001]
# _1FT_CB = [7.980065999999999,6.1960109999999995,4.235079,1.983414,0.9428550000000001,0.7447260000000001,0.5575350000000001]
# carbon_budget_considered = _1FT_CB
# print(carbon_budget_considered)
ft=1
# Out:
# [7.980065999999999 6.1960109999999995 4.235079 1.983414 0.9428550000000001
#  0.7447260000000001 0.5575350000000001]

# %%
for CO2saving, carbon_budget in enumerate(carbon_budget_considered):
    for _in_val in [10,20,30,40,50,70,90,110,130,150]:
        print(_in_val)
        win1 = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=50+_in_val)
        win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=50+_in_val-ft)
        
        av_mat = win.get_av_mat(method='cvxpy_scip', fine_tuning=False, carbon_budget=carbon_budget-win1.get_GHG_matrix().to_numpy()[:,-ft:].sum(), key_word=f"alphaF-{50+_in_val}sl-{CO2saving+1}cb")
        availability_df = pd.DataFrame(np.hstack([av_mat.to_numpy(),np.ones((7,ft))]), index=win.countries, columns=[i for i in range(av_mat.shape[1]+ft)])
        key_word=f"alphaF-{50+_in_val}sl-{CO2saving+1}cb-{ft}ft"
        dict_cols = dict(
        zip([i for i in range(win.n_rounds+ft)], win1.window_list_hours[:win.n_rounds+ft])
    )  # get the datetime values
        availability_matrix_to_save = availability_df.rename(columns=dict_cols)
        availability_matrix_to_save.to_csv(
            win.out_folder + "/av-mat_" + key_word + ".csv",
            columns=win1.window_list_hours[:win.n_rounds+ft],
        )
        # try:
        #     av_mat = win.get_av_mat(method='cvxpy_greedy', fine_tuning=False, carbon_budget=carbon_budget-win1.get_GHG_matrix().to_numpy()[:,-ft:].sum(), key_word=f"alphaF-{50+_in_val}sl-{CO2saving+1}cb")
        #     availability_df = pd.DataFrame(np.hstack([av_mat.to_numpy(),np.ones((7,ft))]), index=win.countries, columns=[i for i in range(av_mat.shape[1]+ft)])
        #     key_word=f"alphaF-{50+_in_val}sl-{CO2saving+1}cb-{ft}ft"
        #     dict_cols = dict(
        #     zip([i for i in range(win.n_rounds+ft)], win1.window_list_hours[:win.n_rounds+ft])
        # )  # get the datetime values
        #     availability_matrix_to_save = availability_df.rename(columns=dict_cols)
        #     availability_matrix_to_save.to_csv(
        #         win.out_folder + "/av-mat_" + key_word + ".csv",
        #         columns=win1.window_list_hours[:win.n_rounds+ft],
        #     )
        # except:
        #     print("Failed !")
        #     continue
    continue
# Out:
# 10
# target:  7.770350999999999
# result:  7.738394999999998
# 20
# target:  7.719029999999999
# result:  7.682591999999997
# 30
# target:  7.635248999999999
# result:  7.627688999999996
# 40
# target:  7.592114999999999
# result:  7.584680999999996
# 50
# target:  7.691795999999999
# result:  7.651532999999997
# 70
# target:  7.666847999999999
# result:  7.643891999999999
# 90
# target:  7.646168999999999
# result:  7.644455999999998
# 110
# target:  7.606259999999999
# result:  7.576109999999992
# 130
# target:  7.678742999999999
# result:  7.672856999999992
# 150
# target:  7.722878999999999
# result:  7.702817999999991
# 10
# target:  5.986295999999999
# result:  5.974613999999997
# 20
# target:  5.934975
# result:  5.887673999999996
# 30
# target:  5.851194
# result:  5.821523999999997
# 40
# target:  5.808059999999999
# result:  5.779706999999996
# 50
# target:  5.907741
# result:  5.867387999999997
# 70
# target:  5.8827929999999995
# result:  5.857307999999998
# 90
# target:  5.862113999999999
# result:  5.860103999999995
# 110
# target:  5.822204999999999
# result:  5.780561999999991
# 130
# target:  5.8946879999999995
# result:  5.891051999999991
# 150
# target:  5.938823999999999
# result:  5.908019999999993
# 10
# target:  4.025364
# result:  4.013778000000001
# 20
# target:  3.974043
# result:  3.959352
# 30
# target:  3.890262
# result:  3.8729009999999997
# 40
# target:  3.8471279999999997
# result:  3.817305
# 50
# target:  3.946809
# result:  3.935781
# 70
# target:  3.921861
# result:  3.9146700000000005
# 90
# target:  3.901182
# result:  3.8963729999999996
# 110
# target:  3.8612729999999997
# result:  3.8522850000000006
# 130
# target:  3.933756
# result:  3.930332999999999
# 150
# target:  3.9778919999999998
# result:  3.9742980000000006
# 10
# target:  1.7736990000000001
# result:  1.7714489999999998
# 20
# target:  1.722378
# result:  1.7162009999999994
# 30
# target:  1.638597
# result:  1.6235339999999996
# 40
# target:  1.595463
# result:  1.5644099999999992
# 50
# target:  1.695144
# result:  1.6892729999999996
# 70
# target:  1.670196
# result:  1.6453109999999995
# 90
# target:  1.649517
# result:  1.6483049999999995
# 110
# target:  1.609608
# result:  1.5945329999999995
# 130
# target:  1.682091
# result:  1.6738019999999991
# 150
# target:  1.726227
# result:  1.7222519999999994
# 10
# target:  0.7331400000000001
# result:  0.7292369999999999
# 20
# target:  0.6818190000000002
# result:  0.679905
# 30
# target:  0.5980380000000002
# result:  0.5950259999999999
# 40
# target:  0.5549040000000002
# result:  0.525897
# 50
# target:  0.6545850000000002
# result:  0.645918
# 70
# target:  0.6296370000000001
# result:  0.6290279999999997
# 90
# target:  0.6089580000000001
# result:  0.6066269999999998
# 110
# target:  0.5690490000000001
# result:  0.5575319999999998
# 130
# target:  0.6415320000000002
# result:  0.6377009999999996
# 150
# target:  0.6856680000000002
# result:  0.6753659999999995
# 10
# target:  0.5350110000000001
# result:  0.532815
# 20
# target:  0.4836900000000001
# result:  0.46719299999999986
# 30
# target:  0.3999090000000002
# result:  0.367023
# 40
# target:  0.3567750000000002
# result:  0.34287899999999993
# 50
# target:  0.45645600000000014
# result:  0.45579599999999987
# 70
# target:  0.4315080000000001
# result:  0.430455
# 90
# target:  0.4108290000000001
# result:  0.409863
# 110
# target:  0.3709200000000001
# result:  0.369162
# 130
# target:  0.44340300000000016
# result:  0.43057500000000004
# 150
# target:  0.4875390000000001
# result:  0.48442199999999996
# 10
# target:  0.34782000000000013
# result:  0.33548999999999984
# 20
# target:  0.2964990000000001
# result:  0.28900499999999985
# 30
# target:  0.21271800000000018
# result:  0.200142
# 40
# target:  0.16958400000000018
# result:  0.16726199999999997
# 50
# target:  0.26926500000000014
# result:  0.2677739999999999
# 70
# target:  0.24431700000000012
# result:  0.24185399999999996
# 90
# target:  0.22363800000000011
# result:  0.2212049999999999
# 110
# target:  0.1837290000000001
# result:  0.1751759999999999
# 130
# target:  0.25621200000000016
# result:  0.2512979999999999
# 150
# target:  0.3003480000000001
# result:  0.2761320000000001

# %%
# ft=3
# for CO2saving, carbon_budget in enumerate(carbon_budget_considered):
#     for _in_val in range(20,101,20):
#         win1 = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
#             countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100+_in_val)
#         win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
#             countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100+_in_val-ft)
#         try:
#             av_mat = win.get_av_mat(method='cvxpy_scip', fine_tuning=False, carbon_budget=carbon_budget-win1.get_GHG_matrix().to_numpy()[:,-ft:].sum(), key_word=f"alphaF-{100+_in_val}sl-{CO2saving+1}cb")
#             availability_df = pd.DataFrame(np.hstack([av_mat.to_numpy(),np.ones((7,ft))]), index=win.countries, columns=[i for i in range(av_mat.shape[1]+ft)])
#             key_word=f"alphaF-{100+_in_val}sl-{CO2saving+1}cb-{ft}ft"
#             dict_cols = dict(
#             zip([i for i in range(win.n_rounds+ft)], win1.window_list_hours[:win.n_rounds+ft])
#         )  # get the datetime values
#             availability_matrix_to_save = availability_df.rename(columns=dict_cols)
#             availability_matrix_to_save.to_csv(
#                 win.out_folder + "/av-mat_" + key_word + ".csv",
#                 columns=win1.window_list_hours[:win.n_rounds+ft],
#             )
#         except:
#             print("Failed !")
#             continue
#     continue

# %%
# alpha_val = 0.1
# for CO2saving,carbon_budget in enumerate(carbon_budget_considered):
#     print("Carbon budget :", carbon_budget)
#     win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
#         countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=50)
#     # for alpha_val in [0.001, 0.01, 0.1, 0.5, 0.75, 0.9, 1.0]:
#     av_mat = win.get_av_mat(method='cvxpy_scip', fine_tuning=False, carbon_budget=carbon_budget, key_word=f"alphaF50-alpha{alpha_val}-{CO2saving+1}cb", alpha_f=alpha_val)

# %%
# CO2saving = 9
# carbon_budget = carbon_budget_considered[CO2saving]
# print("Carbon budget :", carbon_budget)
# win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
#     countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=50)
# for alpha_val in [0.001, 0.01, 0.1, 0.5, 0.75, 0.9, 1.0]:
#     av_mat = win.get_av_mat(method='cvxpy_scip', fine_tuning=False, carbon_budget=carbon_budget, key_word=f"alphaF50-alpha{alpha_val}-{CO2saving+1}cb", alpha_f=alpha_val)
