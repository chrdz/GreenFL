# %% [markdown]
# # Evaluating the output of the SCIP solver of CVXPY

# %%
from av_mat_generation.CI_based.window import Window
from datetime import datetime
import pandas as pd
import numpy as np
import cvxpy as cp
MAIN_FOLDER = 'availability_matrices/av-mat-extn-idle'

start_time=datetime(2022, 1, 1, 0, 0)
win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100)
res = win.get_GHG_matrix()
min_carbon_budget = res[[i for i in range(97,100)]].sum().sum()
total_cb = res.sum().sum()
print(1-min_carbon_budget/total_cb)

print('Total cb: ', total_cb)

win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100)
# Out:
# (CVXPY) Feb 08 10:18:36 AM: Encountered unexpected exception importing solver MPAX:
# RuntimeError('This version of jaxlib was built using AVX instructions, which your CPU and/or operating system do not support. You may be able work around this issue by building jaxlib from source.')
# 0.9636773886552453
# Total cb:  24.152889

# %%
tmp = res.sum().cumsum().to_numpy()

# %%
tmp.take([99])
# Out:
# array([24.152889], dtype=object)

# %%
carbon_budget_considered = res.sum().cumsum().to_numpy().take([39, 29, 19, 9, 4, 3, 2])
print(carbon_budget_considered)

# _3FT_CB = [7.980065999999999,6.1960109999999995,4.235079,1.983414,1.773765,0.9428550000000001,0.7447260000000001]
# _1FT_CB = [7.980065999999999,6.1960109999999995,4.235079,1.983414,0.9428550000000001,0.7447260000000001,0.5575350000000001]
# carbon_budget_considered = _1FT_CB
# print(carbon_budget_considered)
ft=1
# Out:
# [7.980065999999999 6.1960109999999995 4.235079 1.983414 0.9428550000000001
#  0.7447260000000001 0.5575350000000001]

# %%
for CO2saving, carbon_budget in enumerate(carbon_budget_considered):
    for _in_val in [10,20,30,40,50,70,90,110,130,150]:
        print(_in_val)
        win1 = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=50+_in_val)
        win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=50+_in_val-ft)
        
        # Compute new budget with idle time
        C_idle = 0.1
        GHG_mat = win1.GHG_matrix.to_numpy()
        print("x.----------------------- x")
        print("Budget: ", carbon_budget)
        # display(win1.GHG_matrix)
        # print(C_idle*np.sum(GHG_mat))
        new_carbon_budget = (carbon_budget - C_idle*np.sum(GHG_mat))/(1-C_idle)
        print("New Budget: ", new_carbon_budget)
        if new_carbon_budget >= 0:
            try:
                av_mat = win.get_av_mat(method='greedy', fine_tuning=False, carbon_budget=new_carbon_budget-win1.get_GHG_matrix().to_numpy()[:,-ft:].sum(), key_word=f"alphaFidle-{50+_in_val}sl-{CO2saving+1}cb")
                availability_df = pd.DataFrame(np.hstack([av_mat.to_numpy(),np.ones((7,ft))]), index=win.countries, columns=[i for i in range(av_mat.shape[1]+ft)])
                key_word=f"alphaFidle-{50+_in_val}sl-{CO2saving+1}cb-{ft}ft"
                dict_cols = dict(
                zip([i for i in range(win.n_rounds+ft)], win1.window_list_hours[:win.n_rounds+ft])
            )  # get the datetime values
                availability_matrix_to_save = availability_df.rename(columns=dict_cols)
                availability_matrix_to_save.to_csv(
                    win.out_folder + "/av-mat_" + key_word + ".csv",
                    columns=win1.window_list_hours[:win.n_rounds+ft],
                )
            except Exception as e:
                print(f"Failed: {e}")
    continue
# Out:
# 10
# x.----------------------- x
# Budget:  7.980065999999999
# New Budget:  7.563098333333333
# target:  7.3533833333333325
# result:  7.752161699999998
# 20
# x.----------------------- x
# Budget:  7.980065999999999
# New Budget:  7.284303666666665
# target:  7.023267666666666
# result:  7.7161971
# 30
# x.----------------------- x
# Budget:  7.980065999999999
# New Budget:  6.972325333333332
# target:  6.627508333333332
# result:  7.622060999999995
# 40
# x.----------------------- x
# Budget:  7.980065999999999
# New Budget:  6.557789666666665
# target:  6.1698386666666645
# result:  7.566427499999996
# 50
# x.----------------------- x
# Budget:  7.980065999999999
# New Budget:  6.183085666666665
# target:  5.894815666666665
# result:  7.667111099999996
# 70
# x.----------------------- x
# Budget:  7.980065999999999
# New Budget:  5.389799999999998
# target:  5.076581999999998
# result:  7.665306299999997
# 90
# x.----------------------- x
# Budget:  7.980065999999999
# New Budget:  4.604227000000001
# target:  4.27033
# result:  7.620175199999992
# 110
# x.----------------------- x
# Budget:  7.980065999999999
# New Budget:  3.914608000000002
# target:  3.540802000000002
# result:  7.605362699999997
# 130
# x.----------------------- x
# Budget:  7.980065999999999
# New Budget:  3.1609520000000044
# target:  2.8596290000000044
# result:  7.676432699999998
# 150
# x.----------------------- x
# Budget:  7.980065999999999
# New Budget:  2.6016916666666723
# target:  2.3445046666666722
# result:  7.7123151
# 10
# x.----------------------- x
# Budget:  6.1960109999999995
# New Budget:  5.580815
# target:  5.3711
# result:  5.968174499999997
# 20
# x.----------------------- x
# Budget:  6.1960109999999995
# New Budget:  5.302020333333333
# target:  5.040984333333333
# result:  5.9151026999999985
# 30
# x.----------------------- x
# Budget:  6.1960109999999995
# New Budget:  4.990041999999999
# target:  4.645224999999999
# result:  5.850499199999999
# 40
# x.----------------------- x
# Budget:  6.1960109999999995
# New Budget:  4.575506333333332
# target:  4.187555333333332
# result:  5.794009799999998
# 50
# x.----------------------- x
# Budget:  6.1960109999999995
# New Budget:  4.200802333333333
# target:  3.912532333333333
# result:  5.884357799999999
# 70
# x.----------------------- x
# Budget:  6.1960109999999995
# New Budget:  3.407516666666665
# target:  3.094298666666665
# result:  5.850854999999999
# 90
# x.----------------------- x
# Budget:  6.1960109999999995
# New Budget:  2.6219436666666684
# target:  2.2880466666666686
# result:  5.848308299999998
# 110
# x.----------------------- x
# Budget:  6.1960109999999995
# New Budget:  1.9323246666666696
# target:  1.5585186666666695
# result:  5.815565099999997
# 130
# x.----------------------- x
# Budget:  6.1960109999999995
# New Budget:  1.1786686666666717
# target:  0.8773456666666717
# result:  5.875027799999994
# 150
# x.----------------------- x
# Budget:  6.1960109999999995
# New Budget:  0.6194083333333398
# target:  0.3622213333333398
# result:  5.938317899999994
# 10
# x.----------------------- x
# Budget:  4.235079
# New Budget:  3.402001666666667
# target:  3.192286666666667
# result:  3.982959
# 20
# x.----------------------- x
# Budget:  4.235079
# New Budget:  3.123207
# target:  2.862171
# result:  3.9443754000000006
# 30
# x.----------------------- x
# Budget:  4.235079
# New Budget:  2.8112286666666666
# target:  2.4664116666666667
# result:  3.8885198999999986
# 40
# x.----------------------- x
# Budget:  4.235079
# New Budget:  2.3966929999999995
# target:  2.008742
# result:  3.821087399999998
# 50
# x.----------------------- x
# Budget:  4.235079
# New Budget:  2.0219889999999996
# target:  1.7337189999999996
# result:  3.9255347999999977
# 70
# x.----------------------- x
# Budget:  4.235079
# New Budget:  1.2287033333333324
# target:  0.9154853333333324
# result:  3.9211703999999967
# 90
# x.----------------------- x
# Budget:  4.235079
# New Budget:  0.44313033333333546
# target:  0.10923333333333546
# result:  3.893257199999996
# 110
# x.----------------------- x
# Budget:  4.235079
# New Budget:  -0.24648866666666336
# 130
# x.----------------------- x
# Budget:  4.235079
# New Budget:  -1.0001446666666611
# 150
# x.----------------------- x
# Budget:  4.235079
# New Budget:  -1.5594049999999933
# 10
# x.----------------------- x
# Budget:  1.983414
# New Budget:  0.9001516666666671
# target:  0.6904366666666671
# result:  1.7720288999999998
# 20
# x.----------------------- x
# Budget:  1.983414
# New Budget:  0.6213569999999999
# target:  0.36032099999999995
# result:  1.7217434999999988
# 30
# x.----------------------- x
# Budget:  1.983414
# New Budget:  0.3093786666666667
# target:  -0.03543833333333324
# result:  1.6704914999999978
# 40
# x.----------------------- x
# Budget:  1.983414
# New Budget:  -0.10515700000000042
# 50
# x.----------------------- x
# Budget:  1.983414
# New Budget:  -0.4798610000000002
# 70
# x.----------------------- x
# Budget:  1.983414
# New Budget:  -1.2731466666666673
# 90
# x.----------------------- x
# Budget:  1.983414
# New Budget:  -2.058719666666664
# 110
# x.----------------------- x
# Budget:  1.983414
# New Budget:  -2.748338666666663
# 130
# x.----------------------- x
# Budget:  1.983414
# New Budget:  -3.5019946666666613
# 150
# x.----------------------- x
# Budget:  1.983414
# New Budget:  -4.061254999999993
# 10
# x.----------------------- x
# Budget:  0.9428550000000001
# New Budget:  -0.25602499999999934
# 20
# x.----------------------- x
# Budget:  0.9428550000000001
# New Budget:  -0.5348196666666666
# 30
# x.----------------------- x
# Budget:  0.9428550000000001
# New Budget:  -0.8467979999999998
# 40
# x.----------------------- x
# Budget:  0.9428550000000001
# New Budget:  -1.2613336666666668
# 50
# x.----------------------- x
# Budget:  0.9428550000000001
# New Budget:  -1.6360376666666665
# 70
# x.----------------------- x
# Budget:  0.9428550000000001
# New Budget:  -2.429323333333334
# 90
# x.----------------------- x
# Budget:  0.9428550000000001
# New Budget:  -3.2148963333333307
# 110
# x.----------------------- x
# Budget:  0.9428550000000001
# New Budget:  -3.9045153333333293
# 130
# x.----------------------- x
# Budget:  0.9428550000000001
# New Budget:  -4.6581713333333274
# 150
# x.----------------------- x
# Budget:  0.9428550000000001
# New Budget:  -5.21743166666666
# 10
# x.----------------------- x
# Budget:  0.7447260000000001
# New Budget:  -0.4761683333333327
# 20
# x.----------------------- x
# Budget:  0.7447260000000001
# New Budget:  -0.7549629999999999
# 30
# x.----------------------- x
# Budget:  0.7447260000000001
# New Budget:  -1.066941333333333
# 40
# x.----------------------- x
# Budget:  0.7447260000000001
# New Budget:  -1.4814770000000004
# 50
# x.----------------------- x
# Budget:  0.7447260000000001
# New Budget:  -1.856181
# 70
# x.----------------------- x
# Budget:  0.7447260000000001
# New Budget:  -2.6494666666666675
# 90
# x.----------------------- x
# Budget:  0.7447260000000001
# New Budget:  -3.4350396666666643
# 110
# x.----------------------- x
# Budget:  0.7447260000000001
# New Budget:  -4.124658666666663
# 130
# x.----------------------- x
# Budget:  0.7447260000000001
# New Budget:  -4.878314666666661
# 150
# x.----------------------- x
# Budget:  0.7447260000000001
# New Budget:  -5.437574999999993
# 10
# x.----------------------- x
# Budget:  0.5575350000000001
# New Budget:  -0.6841583333333326
# 20
# x.----------------------- x
# Budget:  0.5575350000000001
# New Budget:  -0.962953
# 30
# x.----------------------- x
# Budget:  0.5575350000000001
# New Budget:  -1.2749313333333332
# 40
# x.----------------------- x
# Budget:  0.5575350000000001
# New Budget:  -1.6894670000000003
# 50
# x.----------------------- x
# Budget:  0.5575350000000001
# New Budget:  -2.064171
# 70
# x.----------------------- x
# Budget:  0.5575350000000001
# New Budget:  -2.857456666666667
# 90
# x.----------------------- x
# Budget:  0.5575350000000001
# New Budget:  -3.643029666666664
# 110
# x.----------------------- x
# Budget:  0.5575350000000001
# New Budget:  -4.332648666666663
# 130
# x.----------------------- x
# Budget:  0.5575350000000001
# New Budget:  -5.086304666666662
# 150
# x.----------------------- x
# Budget:  0.5575350000000001
# New Budget:  -5.645564999999993
