# %% [markdown]
# # Evaluating the output of the SCIP solver of CVXPY

# %%
from av_mat_generation.CI_based.window import Window
from datetime import datetime
import pandas as pd
import numpy as np
import cvxpy as cp
MAIN_FOLDER = 'availability_matrices/av-mat-extn'

# %%
start_time=datetime(2022, 1, 1, 0, 0)
win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100)
res = win.get_GHG_matrix()
min_carbon_budget = res[[i for i in range(97,100)]].sum().sum()
total_cb = res.sum().sum()
print(1-min_carbon_budget/total_cb)
win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100)
# Out:
# 0.9636773886552453

# %%
carbon_budget_considered = res.sum().cumsum().to_numpy().take([89,74,59,44,29,14,4])
perc_cb_saved = [100*(i/total_cb) for i in carbon_budget_considered]
print(carbon_budget_considered)
print(perc_cb_saved)
# Out:
# [20.780553 15.540347999999996 11.732774999999997 8.838905999999998
#  6.1960109999999995 3.032562 0.9428550000000001]

# %%
ft=3
for CO2saving, carbon_budget in enumerate(carbon_budget_considered):
    for _in_val in range(20,101,20):
        win1 = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100+_in_val)
        win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100+_in_val-ft)
        try:
            av_mat = win.get_av_mat(method='cvxpy_scip', fine_tuning=False, carbon_budget=carbon_budget-win1.get_GHG_matrix().to_numpy()[:,-ft:].sum(), key_word=f"alphaF-{100+_in_val}sl-{CO2saving+1}cb")
            availability_df = pd.DataFrame(np.hstack([av_mat.to_numpy(),np.ones((7,ft))]), index=win.countries, columns=[i for i in range(av_mat.shape[1]+ft)])
            key_word=f"alphaF-{100+_in_val}sl-{CO2saving+1}cb-{ft}ft"
            dict_cols = dict(
            zip([i for i in range(win.n_rounds+ft)], win1.window_list_hours[:win.n_rounds+ft])
        )  # get the datetime values
            availability_matrix_to_save = availability_df.rename(columns=dict_cols)
            availability_matrix_to_save.to_csv(
                win.out_folder + "/av-mat_" + key_word + ".csv",
                columns=win1.window_list_hours[:win.n_rounds+ft],
            )
        except:
            print("Failed !")
            continue
    continue
# Out:
# target:  19.775286
# result:  19.610549999999996
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  19.715007
# result:  19.707078000000013
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  19.694202
# result:  19.636641000000033
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  19.875405
# result:  19.715982000000025
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  20.069097000000003
# result:  20.031258000000012
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  14.535080999999996
# result:  14.534748000000004
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  14.474801999999997
# result:  14.471912999999999
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  14.453996999999996
# result:  14.453457000000004
# target:  14.635199999999996
# result:  14.634891000000003
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  14.828891999999996
# result:  14.828598000000005
# target:  10.727507999999997
# result:  10.664538000000004
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  10.667228999999997
# result:  10.623587999999996
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  10.646423999999996
# result:  10.644995999999997
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  10.827626999999996
# result:  10.826810999999996
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  11.021318999999997
# result:  11.021313
# target:  7.833638999999998
# result:  7.781585999999998
# target:  7.7733599999999985
# result:  7.670210999999994
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  7.752554999999998
# result:  7.750994999999991
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  7.933757999999998
# result:  7.91126699999999
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  8.127449999999998
# result:  8.12682899999999
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.190744
# result:  5.190588
# target:  5.130465
# result:  5.130332999999997
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.10966
# result:  5.1096599999999945
# target:  5.290863
# result:  5.290580999999994
# target:  5.484554999999999
# result:  5.484383999999998
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.027295
# result:  2.0272290000000015
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  1.9670160000000003
# result:  1.9651680000000002
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  1.9462110000000001
# result:  1.9462110000000008
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.127414
# result:  2.1273870000000006
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.321106
# result:  2.3201970000000007
# Failed !
# Failed !
# Failed !
# target:  0.03770700000000016
# result:  0.03750299999999999
# /home/danny/Documents/prjkts/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.23139900000000013
# result:  0.2312519999999999

# %%
carbon_budget_considered = res.sum().cumsum().to_numpy().take([89,74,59,44,29,14,4,2])
perc_cb_saved = [100*(i/total_cb) for i in carbon_budget_considered]
print(carbon_budget_considered)
print(perc_cb_saved)
# Out:
# [20.780553 15.540347999999996 11.732774999999997 8.838905999999998
#  6.1960109999999995 3.032562 0.9428550000000001 0.5575350000000001]
# [86.03754606747044, 64.34157007056174, 48.57710810495588, 36.59564700520919, 25.653291413710384, 12.555690542858041, 3.903694502135956, 2.3083573977423577]

# %%
ft=1
for CO2saving, carbon_budget in enumerate(carbon_budget_considered):
    for _in_val in range(20,101,20):
        win1 = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100+_in_val)
        win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100+_in_val-ft)
        try:
            av_mat = win.get_av_mat(method='cvxpy_scip', fine_tuning=False, carbon_budget=carbon_budget-win1.get_GHG_matrix().to_numpy()[:,-ft:].sum(), key_word=f"alphaF-{100+_in_val}sl-{CO2saving+1}cb")
            availability_df = pd.DataFrame(np.hstack([av_mat.to_numpy(),np.ones((7,ft))]), index=win.countries, columns=[i for i in range(av_mat.shape[1]+ft)])
            key_word=f"alphaF-{100+_in_val}sl-{CO2saving+1}cb-{ft}ft"
            dict_cols = dict(
            zip([i for i in range(win.n_rounds+ft)], win1.window_list_hours[:win.n_rounds+ft])
        )  # get the datetime values
            availability_matrix_to_save = availability_df.rename(columns=dict_cols)
            availability_matrix_to_save.to_csv(
                win.out_folder + "/av-mat_" + key_word + ".csv",
                columns=win1.window_list_hours[:win.n_rounds+ft],
            )
        except Exception as e:
            print(f"Failed! Exception: {e}")
            continue
    continue
# Out:
# target:  20.467335000000002
# result:  20.465910000000004
# target:  20.446656
# result:  20.445177000000005
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  20.406747000000003
# result:  20.405547000000034
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  20.47923
# result:  20.477877000000042
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  20.523366000000003
# result:  20.468799000000004
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  15.227129999999995
# result:  15.226923000000006
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  15.206450999999996
# result:  15.205419000000003
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  15.166541999999996
# result:  15.164702999999998
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  15.239024999999996
# result:  15.23826
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  15.283160999999996
# result:  15.282498000000002
# target:  11.419556999999998
# result:  11.418378000000002
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  11.398877999999996
# result:  11.377146000000002
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  11.358968999999997
# result:  11.357888999999998
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  11.431451999999997
# result:  11.430434999999996
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  11.475587999999997
# result:  11.449857
# target:  8.525687999999999
# result:  8.474126999999998
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  8.505008999999998
# result:  8.504985
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  8.465099999999998
# result:  8.465051999999993
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  8.537582999999998
# result:  8.537159999999991
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  8.581718999999998
# result:  8.581622999999993
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.8827929999999995
# result:  5.882762999999997
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.862113999999999
# result:  5.861858999999996
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.822204999999999
# result:  5.821850999999995
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.8946879999999995
# result:  5.894555999999997
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.938823999999999
# result:  5.926238999999997
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.719344
# result:  2.7193109999999994
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.698665
# result:  2.689794
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.658756
# result:  2.6584860000000003
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.731239
# result:  2.731098
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.775375
# result:  2.775024000000001
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.6296370000000001
# result:  0.6290279999999996
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.6089580000000001
# result:  0.6087269999999999
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.5690490000000001
# result:  0.5690189999999999
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.6415320000000002
# result:  0.6413129999999996
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.6856680000000002
# result:  0.6855479999999995
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.24431700000000012
# result:  0.24383699999999997
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.22363800000000011
# result:  0.22329299999999994
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.1837290000000001
# result:  0.1837109999999999
# target:  0.25621200000000016
# result:  0.25611899999999993
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.3003480000000001
# result:  0.300108
