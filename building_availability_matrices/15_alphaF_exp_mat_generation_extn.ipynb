# %% [markdown]
# # Evaluating the output of the SCIP solver of CVXPY

# %%
from av_mat_generation.CI_based.window import Window
from datetime import datetime
import pandas as pd
import numpy as np
import cvxpy as cp
MAIN_FOLDER = 'availability_matrices/av-mat-extn-new'

# %%
start_time=datetime(2022, 1, 1, 0, 0)
win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100)
res = win.get_GHG_matrix()
min_carbon_budget = res[[i for i in range(97,100)]].sum().sum()
total_cb = res.sum().sum()
print(1-min_carbon_budget/total_cb)
win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100)
# Out:
# 0.9636773886552453

# %%
carbon_budget_considered = res.sum().cumsum().to_numpy().take([89,74,59,44,29,14,4])
perc_cb_saved = [100*(i/total_cb) for i in carbon_budget_considered]
print(carbon_budget_considered)
print(perc_cb_saved)
# Out:
# [20.780553 15.540347999999996 11.732774999999997 8.838905999999998
#  6.1960109999999995 3.032562 0.9428550000000001]
# [86.03754606747044, 64.34157007056174, 48.57710810495588, 36.59564700520919, 25.653291413710384, 12.555690542858041, 3.903694502135956]

# %%
ft=3
T = [90,75,60,45,30,15,5]
for CO2saving, carbon_budget in enumerate(carbon_budget_considered):
    print(T[CO2saving])
    for _in_val in [10,20,30,40,50]:
        win1 = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=T[CO2saving]+_in_val)
        win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=T[CO2saving]+_in_val-ft)
        try:
            av_mat = win.get_av_mat(method='cvxpy_scip', fine_tuning=False, carbon_budget=carbon_budget-win1.get_GHG_matrix().to_numpy()[:,-ft:].sum(), key_word=f"alphaF-{T[CO2saving]+_in_val}sl-{CO2saving+1}cb")
            availability_df = pd.DataFrame(np.hstack([av_mat.to_numpy(),np.ones((7,ft))]), index=win.countries, columns=[i for i in range(av_mat.shape[1]+ft)])
            key_word=f"alphaF-{T[CO2saving]+_in_val}sl-{CO2saving+1}cb-{ft}ft"
            dict_cols = dict(
            zip([i for i in range(win.n_rounds+ft)], win1.window_list_hours[:win.n_rounds+ft])
        )  # get the datetime values
            availability_matrix_to_save = availability_df.rename(columns=dict_cols)
            availability_matrix_to_save.to_csv(
                win.out_folder + "/av-mat_" + key_word + ".csv",
                columns=win1.window_list_hours[:win.n_rounds+ft],
            )
        except Exception as e:
            print(f"Failed! Exception: {e}")
            continue
    continue
# Out:
# 90
# target:  19.903257
# result:  19.9030458
# target:  19.727139
# result:  19.724991600000003
# target:  19.775286
# result:  19.774756200000006
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  19.621731
# result:  19.62093120000001
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  19.715007
# result:  19.713855000000002
# 75
# target:  14.421611999999996
# result:  14.420552400000005
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  14.461811999999997
# result:  14.430663000000003
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  14.476028999999997
# result:  14.446206599999998
# target:  14.366813999999996
# result:  14.366742600000006
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  14.567864999999996
# result:  14.567744999999988
# 60
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  10.935203999999997
# result:  10.8905856
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  10.771577999999996
# result:  10.701151799999998
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  10.595891999999997
# result:  10.551053999999995
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  10.855478999999997
# result:  10.854683399999995
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  10.679360999999997
# result:  10.679302799999997
# 45
# target:  8.268959999999998
# result:  8.146265999999997
# target:  8.099801999999999
# result:  8.099284799999994
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  8.055035999999998
# result:  8.054230799999996
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  7.720169999999998
# result:  7.719644399999996
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  7.760369999999998
# result:  7.760042999999996
# 30
# target:  5.677328999999999
# result:  5.514638399999999
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.638319999999999
# result:  5.635849200000003
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.562873
# result:  5.562090600000003
# target:  5.398439999999999
# result:  5.397976799999999
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.234813999999999
# result:  5.234645399999996
# 15
# target:  2.433147
# result:  2.4315822000000002
# target:  2.485659
# result:  2.4846252
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.518941
# result:  2.5188378
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.462616
# result:  2.462214000000001
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# 5
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'

# %%
carbon_budget_considered = res.sum().cumsum().to_numpy().take([89,74,59,44,29,14,4,2])
perc_cb_saved = [100*(i/total_cb) for i in carbon_budget_considered]
print(carbon_budget_considered)
print(perc_cb_saved)
# Out:
# [20.780553 15.540347999999996 11.732774999999997 8.838905999999998
#  6.1960109999999995 3.032562 0.9428550000000001 0.5575350000000001]
# [86.03754606747044, 64.34157007056174, 48.57710810495588, 36.59564700520919, 25.653291413710384, 12.555690542858041, 3.903694502135956, 2.3083573977423577]

# %%
ft=1
T = [90,75,60,45,30,15,5,3]
for CO2saving, carbon_budget in enumerate(carbon_budget_considered):
    print(T[CO2saving])
    for _in_val in [10,20,30,40,50]:
        win1 = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=T[CO2saving]+_in_val)
        win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=T[CO2saving]+_in_val-ft)
        try:
            av_mat = win.get_av_mat(method='cvxpy_scip', fine_tuning=False, carbon_budget=carbon_budget-win1.get_GHG_matrix().to_numpy()[:,-ft:].sum(), key_word=f"alphaF-{T[CO2saving]+_in_val}sl-{CO2saving+1}cb")
            availability_df = pd.DataFrame(np.hstack([av_mat.to_numpy(),np.ones((7,ft))]), index=win.countries, columns=[i for i in range(av_mat.shape[1]+ft)])
            key_word=f"alphaF-{T[CO2saving]+_in_val}sl-{CO2saving+1}cb-{ft}ft"
            dict_cols = dict(
            zip([i for i in range(win.n_rounds+ft)], win1.window_list_hours[:win.n_rounds+ft])
        )  # get the datetime values
            availability_matrix_to_save = availability_df.rename(columns=dict_cols)
            availability_matrix_to_save.to_csv(
                win.out_folder + "/av-mat_" + key_word + ".csv",
                columns=win1.window_list_hours[:win.n_rounds+ft],
            )
        except Exception as e:
            print(f"Failed! Exception: {e}")
            continue
    continue
# Out:
# 90
# target:  20.492283
# result:  20.490876600000004
# target:  20.424231000000002
# result:  20.416021199999996
# target:  20.467335000000002
# result:  20.42305080000001
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  20.400867
# result:  20.399863200000013
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  20.446656
# result:  20.445780000000003
# 75
# target:  15.166559999999997
# result:  15.162661200000002
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  15.196103999999997
# result:  15.195895800000004
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  15.178487999999996
# result:  15.177307200000001
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  15.150830999999997
# result:  15.150826799999999
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  15.208019999999996
# result:  15.169579199999998
# 60
# target:  11.471738999999996
# result:  11.470851000000003
# target:  11.387957999999998
# result:  11.3454006
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  11.344823999999997
# result:  11.3435484
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  11.444504999999996
# result:  11.444465399999991
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  11.376452999999996
# result:  11.376008399999996
# 45
# target:  8.643770999999997
# result:  8.643181799999995
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  8.578739999999998
# result:  8.534458799999994
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  8.577851999999998
# result:  8.575904399999997
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  8.465117999999999
# result:  8.446913999999992
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  8.494661999999998
# result:  8.494109399999996
# 30
# target:  6.023333999999999
# result:  6.022204199999998
# target:  6.008139
# result:  6.007948200000001
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.986295999999999
# result:  5.985588000000002
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.934975
# result:  5.9349582000000005
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.851194
# result:  5.850166199999998
# 15
# target:  2.838069
# result:  2.836319399999999
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.855091
# result:  2.853846
# target:  2.863668
# result:  2.8633536
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.837427
# result:  2.8372770000000003
# target:  2.772396
# result:  2.772394799999998
# 5
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.7237710000000002
# result:  0.7214988
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# 3
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
