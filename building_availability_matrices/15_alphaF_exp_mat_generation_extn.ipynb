# %% [markdown]
# # Evaluating the output of the SCIP solver of CVXPY

# %%
from av_mat_generation.CI_based.window import Window
from datetime import datetime
import pandas as pd
import numpy as np
import cvxpy as cp
MAIN_FOLDER = 'availability_matrices/av-mat-extn-cifar10-10thFeb'

# %%
start_time=datetime(2022, 1, 1, 0, 0)
win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100)
res = win.get_GHG_matrix()
min_carbon_budget = res[[i for i in range(97,100)]].sum().sum()
total_cb = res.sum().sum()
print(1-min_carbon_budget/total_cb)
win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=100)
# Out:
# 0.9636773886552453

# %%
carbon_budget_considered = res.sum().cumsum().to_numpy().take([89,74,59,44,29,14,4])
perc_cb_saved = [100*(i/total_cb) for i in carbon_budget_considered]
print(carbon_budget_considered)
print(perc_cb_saved)
# Out:
# [20.780553 15.540347999999996 11.732774999999997 8.838905999999998
#  6.1960109999999995 3.032562 0.9428550000000001]
# [86.03754606747044, 64.34157007056174, 48.57710810495588, 36.59564700520919, 25.653291413710384, 12.555690542858041, 3.903694502135956]

# %%
ft=3
T = [90,75,60,45,30,15,5]
for CO2saving, carbon_budget in enumerate(carbon_budget_considered):
    print(T[CO2saving])
    for _in_val in [20,40,60,80,100]:
        win1 = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=T[CO2saving]+_in_val)
        win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=T[CO2saving]+_in_val-ft)
        try:
            av_mat = win.get_av_mat(method='cvxpy_scip', fine_tuning=False, carbon_budget=carbon_budget-win1.get_GHG_matrix().to_numpy()[:,-ft:].sum(), key_word=f"alphaF-{T[CO2saving]+_in_val}sl-{CO2saving+1}cb")
            availability_df = pd.DataFrame(np.hstack([av_mat.to_numpy(),np.ones((7,ft))]), index=win.countries, columns=[i for i in range(av_mat.shape[1]+ft)])
            key_word=f"alphaF-{T[CO2saving]+_in_val}sl-{CO2saving+1}cb-{ft}ft"
            dict_cols = dict(
            zip([i for i in range(win.n_rounds+ft)], win1.window_list_hours[:win.n_rounds+ft])
        )  # get the datetime values
            availability_matrix_to_save = availability_df.rename(columns=dict_cols)
            availability_matrix_to_save.to_csv(
                win.out_folder + "/av-mat_" + key_word + ".csv",
                columns=win1.window_list_hours[:win.n_rounds+ft],
            )
        except Exception as e:
            print(f"Failed! Exception: {e}")
            continue
    continue
# Out:
# 90
# target:  19.727139
# result:  19.721241
# target:  19.621731
# result:  19.573392000000002
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  19.983681
# result:  19.983255000000025
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  19.794975
# result:  19.755771000000028
# target:  20.001684
# result:  20.00149500000003
# 75
# target:  14.461811999999997
# result:  14.409357000000007
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  14.366813999999996
# result:  14.366340000000006
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  14.475911999999996
# result:  14.475180000000002
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  14.512832999999997
# result:  14.511756000000002
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  14.599313999999996
# result:  14.598939000000001
# 60
# target:  10.771577999999996
# result:  10.771056000000005
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  10.855478999999997
# result:  10.855085999999996
# target:  10.727507999999997
# result:  10.664538000000004
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  10.667228999999997
# result:  10.623587999999996
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  10.646423999999996
# result:  10.644995999999997
# 45
# target:  8.099801999999999
# result:  8.099552999999995
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  7.720169999999998
# result:  7.719881999999996
# target:  7.774586999999998
# result:  7.774583999999998
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  7.8664229999999975
# result:  7.865000999999998
# target:  7.991177999999998
# result:  7.990985999999996
# 30
# target:  5.638319999999999
# result:  5.556527999999998
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.398439999999999
# result:  5.372321999999997
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.059127999999999
# result:  5.0571209999999995
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.142596999999999
# result:  5.1425730000000005
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.037189
# result:  5.0371019999999955
# 15
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.485659
# result:  2.484179999999999
# target:  2.462616
# result:  2.4422759999999992
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.248692
# result:  2.247558
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  1.954026
# result:  1.9530060000000005
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  1.8590280000000003
# result:  1.8587370000000007
# 5
# target:  0.3434400000000002
# result:  0.34234200000000004
# target:  0.4292340000000002
# result:  0.42843899999999996
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.20375100000000024
# result:  0.20345700000000005
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# Failed! Exception: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'

# %%
carbon_budget_considered = res.sum().cumsum().to_numpy().take([89,74,59,44,29,14,4,2])
perc_cb_saved = [100*(i/total_cb) for i in carbon_budget_considered]
print(carbon_budget_considered)
print(perc_cb_saved)
# Out:
# [20.780553 15.540347999999996 11.732774999999997 8.838905999999998
#  6.1960109999999995 3.032562 0.9428550000000001 0.5575350000000001]
# [86.03754606747044, 64.34157007056174, 48.57710810495588, 36.59564700520919, 25.653291413710384, 12.555690542858041, 3.903694502135956, 2.3083573977423577]

# %%
ft=1
T = [90,75,60,45,30,15,5,3]
for CO2saving, carbon_budget in enumerate(carbon_budget_considered):
    print(T[CO2saving])
    for _in_val in [20,40,60,80,100]:
        win1 = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=T[CO2saving]+_in_val)
        win = Window(start_time=start_time,random_start=False, out_folder=MAIN_FOLDER, \
            countries=["Belgium", "Ireland", "Germany", "France", "Great Britain", "Finland", "Sweden"], n_rounds=T[CO2saving]+_in_val-ft)
        try:
            av_mat = win.get_av_mat(method='cvxpy_scip', fine_tuning=False, carbon_budget=carbon_budget-win1.get_GHG_matrix().to_numpy()[:,-ft:].sum(), key_word=f"alphaF-{T[CO2saving]+_in_val}sl-{CO2saving+1}cb")
            availability_df = pd.DataFrame(np.hstack([av_mat.to_numpy(),np.ones((7,ft))]), index=win.countries, columns=[i for i in range(av_mat.shape[1]+ft)])
            key_word=f"alphaF-{T[CO2saving]+_in_val}sl-{CO2saving+1}cb-{ft}ft"
            dict_cols = dict(
            zip([i for i in range(win.n_rounds+ft)], win1.window_list_hours[:win.n_rounds+ft])
        )  # get the datetime values
            availability_matrix_to_save = availability_df.rename(columns=dict_cols)
            availability_matrix_to_save.to_csv(
                win.out_folder + "/av-mat_" + key_word + ".csv",
                columns=win1.window_list_hours[:win.n_rounds+ft],
            )
        except Exception as e:
            print(f"Failed! Exception: {e}")
            continue
    continue
# Out:
# 90
# target:  20.424231000000002
# result:  20.347122
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  20.400867
# result:  20.396085000000006
# target:  20.502072000000002
# result:  20.50059600000002
# target:  20.461044
# result:  20.406195000000032
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  20.535399
# result:  20.494260000000022
# 75
# target:  15.196103999999997
# result:  15.193881000000005
# target:  15.150830999999997
# result:  15.150435000000007
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  15.178556999999996
# result:  15.178524000000005
# target:  15.197642999999996
# result:  15.144291000000003
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  15.225926999999997
# result:  15.160926000000003
# 60
# target:  11.387957999999998
# result:  11.387460000000003
# target:  11.444504999999996
# result:  11.391609
# target:  11.419556999999998
# result:  11.418378000000002
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  11.398877999999996
# result:  11.377146000000002
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  11.358968999999997
# result:  11.357888999999998
# 45
# target:  8.578739999999998
# result:  8.573646
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  8.465117999999999
# result:  8.434541999999992
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  8.477045999999998
# result:  8.433278999999994
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  8.506577999999998
# result:  8.506482
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  8.570060999999997
# result:  8.569439999999997
# 30
# target:  6.008139
# result:  6.007964999999997
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.934975
# result:  5.9321999999999955
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.808059999999999
# result:  5.807801999999997
# target:  5.839689
# result:  5.839322999999997
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  5.816324999999999
# result:  5.815574999999997
# 15
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.855091
# result:  2.853356999999999
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.837427
# result:  2.837004
# target:  2.771508
# result:  2.719199999999999
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.688318
# result:  2.687934
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  2.643045
# result:  2.642912999999999
# 5
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.7483620000000001
# result:  0.744504
# target:  0.7739610000000001
# result:  0.7738950000000001
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.6826890000000001
# result:  0.681312
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.5690670000000002
# result:  0.5566949999999999
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.5809950000000002
# result:  0.5809139999999997
# 3
# target:  0.35065800000000014
# result:  0.338058
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.38465400000000016
# result:  0.38394
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.32599200000000017
# result:  0.32524499999999995
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.18660900000000014
# result:  0.186297
# /home/danny/Documents/prjkts/paper/GreenFL/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# target:  0.21561600000000014
# result:  0.21557699999999996
